# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\brend\OneDrive\Desktop\immig_law_docs_500.csv")

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 472  74310a0f38c79645597da2c69d07eeb6
# 473  375696bee5055697aaadd68d46d513ad
# 474  f3daedb307734568fb095ac259b4bf2c
# 475  34d0059d15097950fa9cc1c9d10dfaa9
# 476  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 472   'Lithuanian immigrant family purchase local f...
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Title', 'URL', 'Dates', 'Locations', 'Description', 'Subjects',
#        'Creator', 'Contributor'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           500 non-null    object
#  1   Title        500 non-null    object
#  2   URL          500 non-null    object
#  3   Dates        500 non-null    object
#  4   Locations    424 non-null    object
#  5   Description  413 non-null    object
#  6   Subjects     493 non-null    object
#  7   Creator      476 non-null    object
#  8   Contributor  353 non-null    object
# dtypes: object(9)
# memory usage: 35.3+ KB

# %%
import matplotlib.pyplot as plt

# %%
df.sort_values('Dates')
# Out:
#                                    ID  \
# 461  0052522a3c432a7e3871017a0d1e192c
# 180  98402440f02d055a24f1260eac4bbf23
# 32   8985764ee1de5f8c5eff29fb5d83f5e2
# 426  2f723c38a2da740c189ec64c7558e438
# 304  5e842e5e46308ed1eff8324c1da5f8a7
# ..                                ...
# 135  742939ff78661dfa5f4476c8f54b9b51
# 449  cf742dca460437657a411642e9085e00
# 130  9372cd0dd9995b6e2cf40232a82591ae
# 269  10ca2015a0c3a17c9c29b2a231514a04
# 65   68d2cc272e1681f0c154cfb15c56108f
#
#                                                  Title  \
# 461   "The land prospector's manual and field-book ...
# 180   'Our western empire, or, The new West beyond ...
# 32    'Articles of incorporation and by-laws of the...
# 426   "The land prospector's manual and field-book ...
# 304   'Map of Dakota, drawn from official plats of ...
# ..                                                 ...
# 135   'Oriental exclusion the effect of American im...
# ...

# %%
df.values('Dates')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.values('Dates')
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df['Dates'].values
# Out:
# array(['1921', '1922', '1916', '1927', '1905', '1909', '1905?]', '1891]',
#        '1890]', '1905?]', '1901]', '1894]', '[1901]', '1928', '1920',
#        '1914', '1909', '1926', '1908', '1922', '1912', '1933', '1911',
#        '1945', '1895', '1900', '1917', '1900', '1893', '1930', '1919',
#        '1911', '1882', '1921', '1937', '1910', '1931', '1906', '1893',
#        '1909', '1897]', '1899]', '1909', '1890]', '1911', '1913]',
#        '1901]', '1899]', '1901]', '1912', '1894]', '1901]', '1934',
#        '1945', '1910', '1916', '1940', '1928', '1909', '1904', '1928',
#        '1933', '1912', '1944', '1907', '©1895', '1913', '1898', '1898]',
#        '1907]', '1905?]', '1901]', '1901]', '1906]', '1892]', '1890]',
#        '1900', '1908', '1912', '1897?]', '1905?]', '1917]', '1906',
#        '1905', '1905', '1891]', '1901]', '1912', '1927', '1927',
#        '[1919?]', '1917', '1897?]', '1900]', '1901]', '1907', '1913',
# ...

# %%
df.sort_values('Subjects')
# Out:
#                                    ID  \
# 269  10ca2015a0c3a17c9c29b2a231514a04
# 213  a418defb1c56a4cc75f97e2aded03406
# 315  3bbbcb6f9a9c28622309409d31c42599
# 88   6fd5010c932784e0db200f0c1fd90578
# 370  078aa82623b9e527198958b7f26a25a2
# ..                                ...
# 33   bc494b7328c11eec47b764febaa9e49a
# 87   367626dd392cb8b5a5af01790b7215ed
# 293  0dde8595d34c7a7b4069991ad4819c3a
# 311  3d9cb86ad75b2f9a9ce543cac04ccb97
# 458  d082f15360bb761dec7e81ed0a31590e
#
#                                                  Title  \
# 269   'International law of alien land ownership in...
# 213   'Permit certain "blue discharge" veterans in ...
# 315   'Certificate to the Supreme Court of the Unit...
# 88    'Applicant for admission as lawful wife- uppe...
# 370   'Supplementing naturalization laws. February ...
# ..                                                 ...
# 33    'Immigration laws : Act of Feb. 5, 1917, and ...
# 87             ' Pamphlet on Harsh Immigration Laws '
# ...

# %%
df['Subjects'].values
#Chinese
#Japanese
#Deportation
#Noncitizens--United States
#Aliens--United States
#Illegal aliens--United States
#Emigration and immigration law
#Citizenship
#Mentally ill
#Women--Legal status
#Women
#Married women--Legal status, laws, etc
#Immigration courts
#Immigration Act of 1924
#Naturalization
#Reading
#Bridges, Harry--Deportation Trial 1939
#United States. Bureau of Immigration
#Filipinos
#Chinese Exclusion Act
# Out:
# array(["  'Emigration and immigration law--United States' ", nan,
#        "  'Working class--Dwellings' ,   'Tenement houses--California' ",
#        "  'Overproduction' ", "  'Emigration and immigration' ",
#        "  'United States. Bureau of Immigration and Naturalization' ,   'Emigration and immigration' ,   'United States' ,   'United States--Emigration and immigration' ",
#        "  'Emigration and immigration law' ,   'Poll tax' ,   'Emigration and immigration' ",
#        "  'Emigration and immigration law' ,   'Emigration and immigration' ",
#        "  'Emigration and immigration law' ,   'Emigration and immigration' ",
#        "  'Emigration and immigration law' ,   'Emigration and immigration' ",
#        "  'Mentally ill' ,   'Immigrants' ,   'Emigration and immigration law' ,   'Emigration and immigration' ",
#        "  'Emigration and immigration law' ,   'Foreign workers' ,   'Government policy' ,   'Domicile' ,   'Emigration and immigration' ",
# ...

# %%
df['Locations'].values
#China
#California
#Hawaii
#New York (State)
#Japan
#Philippines
#Mexico
#Canada
# Out:
# array(["  'United States' ", nan, "  'California' ", nan, nan,
#        "  'United States' ", "  'United States' ", "  'United States' ",
#        "  'United States' ,   'China' ", "  'United States' ",
#        "  'United States' ", "  'United States' ",
#        "  'United States' ,   'China' ", "  'United States' ",
#        "  'United States' ", "  'Utah' ", "  'New York (State)' ",
#        "  'United States' ", "  'United States' ",
#        "  'United States' ,   'California' ", "  'United States' ",
#        "  'United States' ", "  'United States' ", "  'United States' ",
#        "  'United States' ,   'New York (State)' ,   'Massachusetts' ",
#        "  'United States' ", "  'United States' ", "  'United States' ",
#        nan, "  'United States' ", "  'United States' ", "  'Canada' ",
#        "  'California' ", nan, "  'United States' ", "  'United States' ",
#        "  'American Samoa' ", "  'United States' ", "  'Hawaii' ",
# ...

# %%
df['Creator'].values
# Out:
# array([" 'United States' ", " 'United States' ", " 'California' ",
#        " 'Brookings, Robert S. (Robert Somers), 1850-1932' ",
#        " 'Whelpley, J. D. (James Davenport), 1863' ", " 'United States' ",
#        " 'United States Congress House (59th, 1st session : 1905-1906)' ",
#        " 'United States Congress House. (51st, 2nd session : 1890-1891)' ",
#        " 'United States Department of the Treasury. Office of the Secretary' ",
#        " 'United States Congress House. (59th, 1st session : 1905-1906)' ",
#        " 'United States Congress House. (56th, 2nd session : 1900-1901)' ",
#        " 'United States Congress House. (53rd, 2nd session : 1893-1894)' ",
#        " 'United States Congress Senate. (57th, 1st session : 1901-1902)' ",
#        " 'United States. Congress. Senate. Committee on Immigration' ",
#        " 'United States' ", nan,
#        " 'New York (State) Commission of Immigration' ",
# ...

# %%
df['Contributor'].values
#United States. Bureau of Immigration
#United States. Immigration and Naturalization Service
#O\'Grady, James Mary Early, 1863-1928
#Dillingham, William P. (William Paul), 1843-1923
#Lodge, Henry Cabot, 1850-1924
#United States Congress. House. Committee on Immigration and Naturalization
#United States Congress. Senate. Committee on Immigration
#Dillingham, William P. (William Paul), 1843-1923
# Out:
# array([" 'United States. Bureau of Immigration' ",
#        " 'United States. Bureau of Immigration' ",
#        " 'California. Commission of Immigration and Housing' ", nan, nan,
#        nan,
#        " 'Knowland, Joseph R. (Joseph Russell), 1873-1966', 'United States Congress. House. Committee on Immigration and Naturalization', 'Immigration Collection of Prescott Farnsworth Hall (Harvard College Library)' ",
#        " 'Oates, William C. (William Calvin), 1835-1910', 'United States Congress. House. Committee on the Judiciary', 'Immigration Collection of Prescott Farnsworth Hall (Harvard College Library)' ",
#        " 'United States Congress Senate. (51st, 1st session : 1889-1890)', 'United States Congress. Senate. Committee on Immigration', 'Immigration Collection of Prescott Farnsworth Hall (Harvard College Library)' ",
# ...

# %%
df.sort_values('Dates', inplace = True)

# %%
df
# Out:
#                                    ID  \
# 461  0052522a3c432a7e3871017a0d1e192c
# 180  98402440f02d055a24f1260eac4bbf23
# 32   8985764ee1de5f8c5eff29fb5d83f5e2
# 426  2f723c38a2da740c189ec64c7558e438
# 304  5e842e5e46308ed1eff8324c1da5f8a7
# ..                                ...
# 135  742939ff78661dfa5f4476c8f54b9b51
# 449  cf742dca460437657a411642e9085e00
# 130  9372cd0dd9995b6e2cf40232a82591ae
# 269  10ca2015a0c3a17c9c29b2a231514a04
# 65   68d2cc272e1681f0c154cfb15c56108f
#
#                                                  Title  \
# 461   "The land prospector's manual and field-book ...
# 180   'Our western empire, or, The new West beyond ...
# 32    'Articles of incorporation and by-laws of the...
# 426   "The land prospector's manual and field-book ...
# 304   'Map of Dakota, drawn from official plats of ...
# ..                                                 ...
# 135   'Oriental exclusion the effect of American im...
# ...

# %%
df.value_counts('Dates')
# Out:
# Dates
# 1902      25
# 1916      22
# 1906]     22
# 1912      21
# 1901]     20
#           ..
# 1923       1
# 1923]      1
# 1924]      1
# 1925?]     1
# ©1895      1
# Name: count, Length: 106, dtype: int64

# %%
df.value_counts('Locations')
# Out:
# Locations
#   'United States'                                                                                                                                                                         337
#   'United States' ,   'China'                                                                                                                                                              18
#   'Canada'                                                                                                                                                                                  6
#   'California'                                                                                                                                                                              5
#   'New York (State)'                                                                                                                                                                        4
# ...

# %%
df.value_counts('Subjects')
# Out:
# Subjects
#   'Emigration and immigration law' ,   'Emigration and immigration'                                                                                             117
#   'Ellis Island Immigration Station (N.Y. and N.J.)'                                                                                                             22
#   'Emigration and immigration law'                                                                                                                               20
#   'Emigration and immigration law--United States'                                                                                                                14
#   'Emigration and immigration law' ,   'Reading' ,   'Ability testing' ,   'Emigration and immigration'                                                          10
# ...

# %%
type(df['Subjects'])
# Out:
# pandas.core.series.Series

# %%
df.value_counts('Subjects','Emigration and immigration')
# Out:
# Subjects
#   'Emigration and immigration law' ,   'Emigration and immigration'                                                                                             0.237323
#   'Ellis Island Immigration Station (N.Y. and N.J.)'                                                                                                            0.044625
#   'Emigration and immigration law'                                                                                                                              0.040568
#   'Emigration and immigration law--United States'                                                                                                               0.028398
#   'Emigration and immigration law' ,   'Reading' ,   'Ability testing' ,   'Emigration and immigration'                                                         0.020284
# ...

# %%
df['Subjects'].str.contains("Chinese")
# Out:
# 461    False
# 180    False
# 32     False
# 426    False
# 304    False
#        ...
# 135     True
# 449    False
# 130    False
# 269    False
# 65     False
# Name: Subjects, Length: 500, dtype: object

# %%
df.value_counts('Creator')
# Out:
# Creator
# 'United States. Congress. House. Committee on Immigration and Naturalization'     38
# 'United States'                                                                   35
# 'United States Congress. House. Committee on Immigration and Naturalization'      27
# 'United States Congress House. (59th, 1st session : 1905-1906)'                   20
# 'Levick, Edwin, 1869-1929'                                                        16
#                                                                                   ..
# 'McKenzie, Roderick Duncan, 1885-1940'                                             1
# 'Mitchell, Ruth Crawford, 1890'                                                    1
# 'Morse, Elijah Adams, 1841-1898'                                                   1
# 'New Jersey. Commission of Immigration'                                            1
# 'Young, James'                                                                     1
# ...

# %%
df
# Out:
#                                    ID  \
# 461  0052522a3c432a7e3871017a0d1e192c
# 180  98402440f02d055a24f1260eac4bbf23
# 32   8985764ee1de5f8c5eff29fb5d83f5e2
# 426  2f723c38a2da740c189ec64c7558e438
# 304  5e842e5e46308ed1eff8324c1da5f8a7
# ..                                ...
# 135  742939ff78661dfa5f4476c8f54b9b51
# 449  cf742dca460437657a411642e9085e00
# 130  9372cd0dd9995b6e2cf40232a82591ae
# 269  10ca2015a0c3a17c9c29b2a231514a04
# 65   68d2cc272e1681f0c154cfb15c56108f
#
#                                                  Title  \
# 461   "The land prospector's manual and field-book ...
# 180   'Our western empire, or, The new West beyond ...
# 32    'Articles of incorporation and by-laws of the...
# 426   "The land prospector's manual and field-book ...
# 304   'Map of Dakota, drawn from official plats of ...
# ..                                                 ...
# 135   'Oriental exclusion the effect of American im...
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Title', 'URL', 'Dates', 'Locations', 'Description', 'Subjects',
#        'Creator', 'Contributor'],
#       dtype='object')

# %%
df['Subjects'] = df['Subjects'].astype(str)

# %%
df[['Subjects_One', 'Subjects_Two', 'Subjects_Three', 'Subjects_Four', 'Subjects_Five']] = df['Subjects'].str.split(',', expand=True, n=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[['Subjects_One', 'Subjects_Two', 'Subjects_Three', 'Subjects_Four', 'Subjects_Five']] = df['Subjects'].str.split(',', expand=True, n=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# ...

# %%
df
# Out:
#                                    ID  \
# 461  0052522a3c432a7e3871017a0d1e192c
# 180  98402440f02d055a24f1260eac4bbf23
# 32   8985764ee1de5f8c5eff29fb5d83f5e2
# 426  2f723c38a2da740c189ec64c7558e438
# 304  5e842e5e46308ed1eff8324c1da5f8a7
# ..                                ...
# 135  742939ff78661dfa5f4476c8f54b9b51
# 449  cf742dca460437657a411642e9085e00
# 130  9372cd0dd9995b6e2cf40232a82591ae
# 269  10ca2015a0c3a17c9c29b2a231514a04
# 65   68d2cc272e1681f0c154cfb15c56108f
#
#                                                  Title  \
# 461   "The land prospector's manual and field-book ...
# 180   'Our western empire, or, The new West beyond ...
# 32    'Articles of incorporation and by-laws of the...
# 426   "The land prospector's manual and field-book ...
# 304   'Map of Dakota, drawn from official plats of ...
# ..                                                 ...
# 135   'Oriental exclusion the effect of American im...
# ...

# %%
type(df['Subjects'])
# Out:
# pandas.core.series.Series

# %%
df[['Subjects_One']] = df['Subjects'].str.split(',', expand=True, n=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df[['Subjects_One']] = df['Subjects'].str.split(',', expand=True, n=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
# ...

# %%
df['Subjects'].shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df['Subjects'].shape()
#
# TypeError: 'tuple' object is not callable

# %%
df[65]['Subjects']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 65
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df[65]['Subjects']
#
# ...

# %%
df['Title']['Law and Lawyers in Seattle's History']
# Out:
#   Cell In[51], line 1
#     df['Title']['Law and Lawyers in Seattle's History']
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import pandas as pd
with pd.option_context('display.max_rows', None):
    print(df)
# Out:
#                                    ID  \
# 461  0052522a3c432a7e3871017a0d1e192c
# 180  98402440f02d055a24f1260eac4bbf23
# 32   8985764ee1de5f8c5eff29fb5d83f5e2
# 426  2f723c38a2da740c189ec64c7558e438
# 304  5e842e5e46308ed1eff8324c1da5f8a7
# 220  80f73a809475bd2757a49f58f95a55ad
# 214  0f0fa7f2f76fdba71dbba88936c7fa3c
# 194  c9d7bc7a43aeab9a921e24d2e879a07d
# 143  68835363a21f4d3d5a7aa815c68b7861
# 291  73bdd7f652b15a60d5dc1c3f827d7753
# 182  72a6b09ca5e685310f04c523fe771004
# 424  efdaac15244440b50fee0389769152e8
# 421  9feaa30228bfc6e262feb91b956a9807
# 272  7b065f29d284a02418e9c5d4a7fe01da
# 152  4532a88296079cc03b44f93034d51f34
# 107  1843529f130999422bc1b379e472a0d6
# 483  1b184ef0f0ad7686fa90b7992eb54f34
# 359  03826549bbd311aaa2c91f8b01f14eba
# 425  58b90b17f724b7c9a0f7776691ea424f
# 75   727f3aeecf8f029fc5b5626e5cc45dd7
# 263  40491e994219d9fc27050bc90aa452b3
# 422  a030fbed0d9a27f6026a67071be73e72
# 169  c6a0e9bfccadf237bb9d1639d9ba6409
# ...

# %%
df.drop(152, axis=0, inplace=True)

# %%
df.drop(316, axis=0, inplace=True)

# %%
df[['Subjects_One', 'Subjects_Two', 'Subjects_Three', 'Subjects_Four', 'Subjects_Five', 'Subjects_Six', 'Subjects_Seven', 'Subjects_Eight', 'Subjects_Nine', 'Subjects_Ten', 'Subjects_Eleven', 'Subjects_Twelve', 'Subjects_Thirteen', 'Subjects_Fourteen', 'Subjects_Fifteen']] = df['Subjects'].str.split(',', expand=True, n=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df[['Subjects_One', 'Subjects_Two', 'Subjects_Three', 'Subjects_Four', 'Subjects_Five', 'Subjects_Six', 'Subjects_Seven', 'Subjects_Eight', 'Subjects_Nine', 'Subjects_Ten', 'Subjects_Eleven', 'Subjects_Twelve', 'Subjects_Thirteen', 'Subjects_Fourteen', 'Subjects_Fifteen']] = df['Subjects'].str.split(',', expand=True, n=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
# ...

# %%
df
# Out:
#                                    ID  \
# 461  0052522a3c432a7e3871017a0d1e192c
# 180  98402440f02d055a24f1260eac4bbf23
# 32   8985764ee1de5f8c5eff29fb5d83f5e2
# 426  2f723c38a2da740c189ec64c7558e438
# 304  5e842e5e46308ed1eff8324c1da5f8a7
# ..                                ...
# 135  742939ff78661dfa5f4476c8f54b9b51
# 449  cf742dca460437657a411642e9085e00
# 130  9372cd0dd9995b6e2cf40232a82591ae
# 269  10ca2015a0c3a17c9c29b2a231514a04
# 65   68d2cc272e1681f0c154cfb15c56108f
#
#                                                  Title  \
# 461   "The land prospector's manual and field-book ...
# 180   'Our western empire, or, The new West beyond ...
# 32    'Articles of incorporation and by-laws of the...
# 426   "The land prospector's manual and field-book ...
# 304   'Map of Dakota, drawn from official plats of ...
# ..                                                 ...
# 135   'Oriental exclusion the effect of American im...
# ...
