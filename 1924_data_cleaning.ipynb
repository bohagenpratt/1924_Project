# %%
import pandas as pd

# %%
df = pd.read_csv('immig_law_docs_500.csv')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
def clean(sample):
  to_remove = ["'", '[', ']']

  for i in to_remove:
    if i in sample:
      sample = sample.replace(i, '')

  return sample

# %%
clean(df)
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Subjects_one'] = df['Subjects_one'].astype(str)
df['Subjects_one'] = df['Subjects_one'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Subjects_two'] = df['Subjects_two'].astype(str)
df['Subjects_two'] = df['Subjects_two'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Subjects_three'] = df['Subjects_three'].astype(str)
df['Subjects_three'] = df['Subjects_three'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Subjects_four'] = df['Subjects_four'].astype(str)
df['Subjects_four'] = df['Subjects_four'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Subjects_five'] = df['Subjects_five'].astype(str)
df['Subjects_five'] = df['Subjects_five'].str.replace("'", ' ')

# %%
df['Subjects_six'] = df['Subjects_six'].astype(str)
df['Subjects_six'] = df['Subjects_six'].str.replace("'", ' ')

# %%
df['Subjects_seven'] = df['Subjects_seven'].astype(str)
df['Subjects_seven'] = df['Subjects_seven'].str.replace("'", ' ')

# %%
df['Subjects_eight'] = df['Subjects_eight'].astype(str)
df['Subjects_eight'] = df['Subjects_eight'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Subjects_nine'] = df['Subjects_nine'].astype(str)
df['Subjects_nine'] = df['Subjects_nine'].str.replace("'", ' ')

# %%
df['Subjects_ten'] = df['Subjects_ten'].astype(str)
df['Subjects_ten'] = df['Subjects_ten'].str.replace("'", ' ')

# %%
df['Subjects_eleven'] = df['Subjects_eleven'].astype(str)
df['Subjects_eleven'] = df['Subjects_eleven'].str.replace("'", ' ')

# %%
df['Subjects_twelve'] = df['Subjects_twelve'].astype(str)
df['Subjects_twelve'] = df['Subjects_twelve'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Location_one'] = df['Location_one'].astype(str)
df['Location_one'] = df['Location_one'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Location_two'] = df['Location_two'].astype(str)
df['Location_two'] = df['Location_two'].str.replace("'", ' ')

# %%
df['Location_three'] = df['Location_three'].astype(str)
df['Location_three'] = df['Location_three'].str.replace("'", ' ')

# %%
df['Location_four'] = df['Location_four'].astype(str)
df['Location_four'] = df['Location_four'].str.replace("'", ' ')

# %%
df['Location_five'] = df['Location_five'].astype(str)
df['Location_five'] = df['Location_five'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Location_five'] = df['Location_five'].astype(str)
df['Location_five'] = df['Location_five'].str.replace("'", ' ')

# %%
df
# Out:
#                                    ID  \
# 0    7da2807b9738bdcc14a7779aed01890b
# 1    d659dfc806ec6fe1665247c0506ca7cb
# 2    13f75136926c493d62935d729cd3453d
# 3    af5ed11f3ed51062a5bd968411043d46
# 4    1360341b5d0d36430d83b0c7af87f456
# ..                                ...
# 464  74310a0f38c79645597da2c69d07eeb6
# 465  375696bee5055697aaadd68d46d513ad
# 466  f3daedb307734568fb095ac259b4bf2c
# 467  34d0059d15097950fa9cc1c9d10dfaa9
# 468  37a2a8fa02d70e287955910c8eec82d4
#
#                                                  Title  \
# 0     'Immigration laws : rules of May 1, 1917 : am...
# 1     'Immigration laws : Act of Feb. 5, 1917, and ...
# 2     'Draft of proposed tenement house law Second ...
# 3     'Overproduction : in its relation to our anti...
# 4     'The problem of the immigrant : a brief discu...
# ..                                                 ...
# 464   'Lithuanian immigrant family purchase local f...
# ...

# %%
df['Dates'] = df['Dates'].astype(str)
df['Dates'] = df['Dates'].str.replace("[", ' ')
df['Dates'] = df['Dates'].str.replace("]", ' ')

# %%
df['Dates'].values
# Out:
# array(['1921', '1922', '1916', '1927', '1905', '1909', '1905? ', '1891 ',
#        '1890 ', '1905? ', '1901 ', '1894 ', ' 1901 ', '1928', '1920',
#        '1914', '1909', '1926', '1908', '1922', '1912', '1933', '1911',
#        '1945', '1895', '1900', '1917', '1900', '1893', '1930', '1919',
#        '1882', '1921', '1937', '1910', '1931', '1906', '1893', '1909',
#        '1897 ', '1899 ', '1909', '1890 ', '1911', '1913 ', '1901 ',
#        '1899 ', '1901 ', '1912', '1894 ', '1901 ', '1934', '1945', '1910',
#        '1940', '1928', '1909', '1904', '1928', '1933', '1912', '1944',
#        '©1895', '1913', '1898', '1898 ', '1907 ', '1905? ', '1901 ',
#        '1901 ', '1906 ', '1892 ', '1890 ', '1900', '1908', '1912',
#        '1897? ', '1905? ', '1917 ', '1906', '1905', '1905', '1891 ',
#        '1901 ', '1912', '1927', '1927', ' 1919? ', '1917', '1897? ',
#        '1900 ', '1901 ', '1907', '1913', '1942', '1920', '1925', '1911',
# ...

# %%
df['Location_one'].values
# Out:
# array(['   United States  ', 'nan', '   California  ', 'nan', 'nan',
#        '   United States  ', '   United States  ', '   United States  ',
#        '   United States  ', '   United States  ', '   United States  ',
#        '   United States  ', '   United States  ', '   United States  ',
#        '   United States  ', '   Utah  ', '   New York (State)  ',
#        '   United States  ', '   United States  ', '   United States  ',
#        '   United States  ', '   United States  ', '   United States  ',
#        '   United States  ', '   United States  ', '   United States  ',
#        '   United States  ', '   United States  ', 'nan',
#        '   United States  ', '   United States  ', '   California  ',
#        'nan', '   United States  ', '   United States  ',
#        '   American Samoa  ', '   United States  ', '   Hawaii  ',
#        '   United States  ', '   United States  ', '   United States  ',
#        '   New York (State)  ', '   United States  ',
# ...

# %%
df['Subjects_two'].values
# Out:
# array(['nan', 'nan', '    Tenement houses--California  ', 'nan', 'nan',
#        '    Emigration and immigration  ', '    Poll tax  ',
#        '    Emigration and immigration  ',
#        '    Emigration and immigration  ',
#        '    Emigration and immigration  ', '    Immigrants  ',
#        '    Foreign workers  ', '    Immigrants  ', 'nan', 'nan',
#        '    Labor laws and legislation--Utah--Periodicals  ',
#        '    New York (State)  ', '    Naturalization--United States  ',
#        '    Emigration and immigration  ', '    Japanese--California  ',
#        'nan', '    Emigration and immigration law--United States  ',
#        '    Emigration and immigration  ',
#        '    Citizenship--United States  ',
#        '    Poor laws--Massachusetts  ', 'nan', 'nan', 'nan', 'nan',
#        '    Students  ', 'nan', 'nan', 'nan', 'nan',
#        '    Emigration and immigration law--United States  ',
#        '    American Samoa--Politics and government  ', '    Chinese  ',
# ...

# %%
df.to_csv('1924proj_docs_clean.csv')
